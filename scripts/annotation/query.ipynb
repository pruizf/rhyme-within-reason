# %% [markdown]
# # Queries into dataset

# %%
import pandas as pd
import re

# %%
cdf = pd.read_csv("../../data/dataframe-all_lem_sets_emos_with_nrc.tsv", sep="\t")
# Out:
# /tmp/ipykernel_14340/498916048.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdf = pd.read_csv("../../data/dataframe-all_lem_sets_emos_with_nrc.tsv", sep="\t")

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85523 entries, 0 to 85522
# Data columns (total 61 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 85523 non-null  object
#  1   SonnetID           85523 non-null  object
#  2   Incipit            85523 non-null  object
#  3   AuthorID           85523 non-null  object
#  4   Author             85523 non-null  object
#  5   Gender             85523 non-null  object
#  6   Date               85523 non-null  object
#  7   LineNumber         85523 non-null  object
#  8   StanzaNumber       85523 non-null  float64
#  9   Text               85523 non-null  object
#  10  Call               85523 non-null  object
#  11  Echo               57595 non-null  object
#  12  Set                85450 non-null  object
#  13  Corpus             85523 non-null  object
#  14  CallLemma          85523 non-null  object
#  15  EchoLemma          85523 non-null  object
# ...

# %% [markdown]
# ## Individual poems

# %%
def format_sonnet(st):
    st = re.sub(r"#+", "\n\n", st)
    st = re.sub(r"~+", "\n", st)
    return st

# %%
myid = 'FernandoDeHerrera_35'
myso = cdf.loc[cdf['SonnetID'] == myid]
mytext = cdf.loc[cdf['SonnetID'] == myid].iloc[0]['Text']

# %%
print(format_sonnet(mytext))
# Out:
# Las hebras que cogía en lazos de oro
# con arte vuestra blanca y tierna mano,
# miraba, y el semblante altivo y llano
# y la florida luz que amando adoro.
#
# Creía en vos del sacro excelso coro
# que el esplendor se unía soberano;
# porque en sombra, aunque bella, y traje humano
# no vio tal bien el orbe y tal tesoro.
#
# Cuando rompiste leda el dulce espanto,
# que de vos parte ausente y solo apena,
# preguntando: «¿Qué fuerza me arrebata?»
#
# Yo, que temo partirme, suelto en llanto,
# digo: «Pienso que a muerte me condena
# del cruel vuestro amor la saña ingrata».

# %% [markdown]
# ## Poem given a list of IDs

# %%
myli = """FernandoDeHerrera_167
JosephDeLitalaYCastelvi_45
ArgensolaLupercio_15
DiegoHurtadoDeMendoza_1
FernandoDeHerrera_273
GutierreDeCetina_241
HernandodeAcunya_52
LopeDeVega_1312
LopeDeVega_630
LopeDeVega_740
LopeDeVega_768
LopeDeVega_928
LopeDeVega_960
LopeDeZarate_19
PedroSotoDeRojas_94
s097g_0193
s478g_1003
AntonioHurtadoDeMendoza_10
FernandoDeHerrera_283
LopeDeVega_596
"""

# smo1
myli = """LuisDeUlloaYPereira_93
s247g_0514
GarcilasoDeLaVega_02
GutierreDeCetina_72
Quevedo_158
JosephDeLitalaYCastelvi_45
FernandoDeHerrera_167
FcodeBorjaYAragonPrincipeEsquilache_114
HernandodeAcunya_52
JuanDeTassisYPeralta_180
LopeDeVega_630
LopeDeVega_596
AntonioHurtadoDeMendoza_10
Quevedo_505
LopeDeVega_1333
GutierreDeCetina_241
s388g_0864
FernandoDeHerrera_246
PedroEspinosa_13
Quevedo_275
"""

# smo1 filter arousal diff <= -0.1
myli = """DiegoHurtadoDeMendoza_1
s315g_0715
LopeDeVega_1004
LopeDeVega_773
s097g_0193
s330g_0775
s472g_0993
LopeDeVega_928
FranciscoDeLaTorre_66
LopeDeVega_1312
s478g_1003
GutierreDeCetina_84
"""

# sm0 filter arousal diff <= -0.2
myli = """GutierreDeCetina_128
DiegoHurtadoDeMendoza_17
JuanDeSalinas_4
JuanBoscan_11
JuanDeTassisYPeralta_163
FcodeBorjaYAragonPrincipeEsquilache_92
Cervantes_50
s125g_0251
HernandodeAcunya_48
CancerYVelasco_11
AntonioEnriquezGomez_13
FranciscoDeAldana_34
LopeDeVega_1226
JosephDeLitalaYCastelvi_79
LopeDeVega_725
Gongora_47
LuisCarrilloySotomayor_17
LopeDeVega_169
LopeDeVega_748
Quevedo_355
LopeDeVega_947
"""

# sort by omsv asc
myli = """GutierreDeCetina_87
Quevedo_313
FernandoDeHerrera_96
LopeDeVega_955
LopeDeVega_1104
Quevedo_474
LuisDeUlloaYPereira_91
GutierreDeCetina_83
PedroDePadilla_9
Quevedo_323
FernandoDeHerrera_128
JuanBoscan_53
s460g_0976
LopeDeVega_785
DiegoHurtadoDeMendoza_15
DiegoHurtadoDeMendoza_41
Cervantes_57
LopeDeZarate_38
FernandoDeHerrera_148
"""

# sm1 -smv after fixing nan and 8-6
myli = """FernandoDeHerrera_35
LopeDeVega_1267
JuanDeTassisYPeralta_171
s113g_0222
LuisDeUlloaYPereira_93
LopeDeVega_911
s247g_0514
s333g_0780
FernandoDeHerrera_170
Quevedo_266
GutierreDeCetina_41
GutierreDeCetina_220
GarcilasoDeLaVega_02
GutierreDeCetina_72
JosephDeLitalaYCastelvi_148
GutierreDeCetina_174
AntonioEnriquezGomez_11
LopeDeVega_795
Quevedo_158
"""

myli = """LopeDeVega_1111
FernandoDeHerrera_245
LopeDeVega_1239
JuanDeTassisYPeralta_164
FernandoDeHerrera_74
FernandoDeHerrera_203
GutierreDeCetina_87
LopeDeZarate_57
FernandoDeHerrera_96
LopeDeVega_955
JuanBoscan_29
LopeDeVega_1104
Quevedo_474
Quevedo_374
TirsoDeMolina_5
LopeDeVega_1314
LopeDeVega_1174
LuisDeUlloaYPereira_80
FernandoDeHerrera_148
JuanDeTassisYPeralta_73
"""


if False:
    # above and omsa <= -0.1
    myli = """FcodeBorjaYAragonPrincipeEsquilache_66
    Quevedo_422
    GutierreDeCetina_90
    JuanDeTassisYPeralta_180
    JosephDeLitalaYCastelvi_95
    LopeDeVega_630
    JosephDeLitalaYCastelvi_150
    Quevedo_505
    LopeDeVega_1333
    GutierreDeCetina_103
    """

    # sm0 after fixing, and osmv asc


# smo0
if False:
    myli = """FernandoDeHerrera_74
    FernandoDeHerrera_203
    GutierreDeCetina_87
    FernandoDeHerrera_96
    LopeDeVega_955
    LopeDeVega_1104
    Quevedo_474
    FernandoDeHerrera_148
    JuanDeTassisYPeralta_73
    BocangelYUnzueta_4
    FernandoDeHerrera_173
    ArgensolaBartolome_155
    s405g_0897
    JuanDeSalinas_7
    ArgensolaLupercio_27
    LopeDeVega_683
    FernandoDeHerrera_150
    FcodeBorjaYAragonPrincipeEsquilache_118
    Quevedo_122
    BernardinoDeRebolledo_15
    """

    # sm0, arousal diff > 0.1

    myli = """Quevedo_323
    FernandoDeHerrera_149
    FernandoDeHerrera_105
    LopeDeVega_1221
    JuanDeTassisYPeralta_109
    JuanDeTassisYPeralta_79
    FernandoDeHerrera_307
    LopeDeVega_26
    GutierreDeCetina_212
    Gongora_93
    JuanDeTimoneda_30
    CancerYVelasco_2
    """

    # sm0, arousal diff > 0.2

    myli = """JuanDeTassisYPeralta_114
    LopeDeVega_785
    LopeDeZarate_38
    Cervantes_8
    Quevedo_306
    Cervantes_49
    LopeDeVega_943
    LopeDeVega_77
    LopeDeVega_1244
    Quevedo_126
    TrilloYFigueroa_9
    LopeDeVega_1254
    s235g_0493
    PoloDeMedina_4
    s406g_0898
    ArgensolaBartolome_101
    LopeDeVega_985
    LopezDeMendoza_40
    """

myids = myli.strip().split("\n")

# %%
# https://stackoverflow.com/questions/23482668/sorting-by-a-custom-list-in-pandas

#myids = ['FernandoDeHerrera_173', 'LopeDeVega_955', 'Quevedo_122', 'FernandoDeHerrera_96', 'LopeDeVega_1104', 'LopeDeVega_683', 'BernardinoDeRebolledo_50', 'DiegoHurtadoDeMendoza_37', 'DiegoXimenezAyllon_49', 'FcodeBorjaYAragonPrincipeEsquilache_70', 'FernandoDeHerrera_105', 'FernandoDeHerrera_128', 'FranciscoDeLaTorre_35', 'GarcilasoDeLaVega_19', 'Gongora_52', 'GutierreDeCetina_202', 'JuanDeArguijo_2', 'JuanDeTassisYPeralta_114', 'JuanDeTassisYPeralta_88', 'JuanDeTimoneda_30']
#myids = ['ArgensolaBartolome_53', 'FcodeBorjaYAragonPrincipeEsquilache_114', 'FernandoDeHerrera_167', 'GarcilasoDeLaVega_02', 'GutierreDeCetina_72', 'GutierreDeCetina_82', 'HernandodeAcunya_47', 'JosephDeLitalaYCastelvi_45', 'JuanDeJauregui_19', 'JuanDeTassisYPeralta_43', 'LopeDeVega_836', 'LuisDeUlloaYPereira_93', 'Quevedo_158', 's247g_0514', 'AntonioHurtadoDeMendoza_10', 'ArgensolaBartolome_23', 'ArgensolaLupercio_15', 'ArgensolaLupercio_48', 'ArgensolaLupercio_50', 'BernardinoDeRebolledo_16']
#myids = ['FcodeBorjaYAragonPrincipeEsquilache_114', 'GarcilasoDeLaVega_02', 'GutierreDeCetina_72', 'LuisDeUlloaYPereira_93', 'Quevedo_158', 's247g_0514', 'FernandoDeHerrera_167', 'JosephDeLitalaYCastelvi_45', 'ArgensolaLupercio_48', 'ArgensolaLupercio_50', 'DiegoXimenezAyllon_28', 'FernandoDeHerrera_246', 'FernandoDeHerrera_286', 'GarcilasoDeLaVega_05', 'Gongora_48', 'GutierreDeCetina_84', 'JosephDeLitalaYCastelvi_107', 'JuanBoscan_92', 'JuanDeTassisYPeralta_169', 'JuanDeTassisYPeralta_180']
#myids = ['FernandoDeHerrera_203', 'FernandoDeHerrera_74', 'ArgensolaLupercio_27', 'BernardinoDeRebolledo_15', 'FcodeBorjaYAragonPrincipeEsquilache_118', 'FernandoDeHerrera_150', 'JuanDeSalinas_7', 'JuanDeTassisYPeralta_73', 'ArgensolaBartolome_155', 'BocangelYUnzueta_4', 'FernandoDeHerrera_148', 'FernandoDeHerrera_173', 'GutierreDeCetina_87', 'LopeDeVega_955', 'Quevedo_122', 'Quevedo_474', 's405g_0897', 'FernandoDeHerrera_96', 'LopeDeVega_1104', 'LopeDeVega_683']
#myids = ['FernandoDeHerrera_74', 'FernandoDeHerrera_173', 'FernandoDeHerrera_96', 'LopeDeVega_1104', 'LopeDeVega_683', 'LopeDeVega_955', 'Quevedo_122', 'BaltasarDeAlcazar_11', 'BernardinoDeRebolledo_50', 'CancerYVelasco_2', 'DiegoHurtadoDeMendoza_37', 'DiegoXimenezAyllon_49', 'FcodeBorjaYAragonPrincipeEsquilache_105', 'FcodeBorjaYAragonPrincipeEsquilache_70', 'FcodeBorjaYAragonPrincipeEsquilache_90', 'FernandoDeHerrera_105', 'FernandoDeHerrera_128', 'FernandoDeHerrera_307', 'FranciscoDeLaTorre_35', 'GarcilasoDeLaVega_19']

#myids = [1312, 630, 740, 768, 928, 960]
#full_ids = [f"LopeDeVega_{str(x)}" for x in myids]

full_ids = myids
myso = cdf.loc[cdf['SonnetID'].isin(full_ids)].drop_duplicates(subset=['SonnetID'])

myso.SonnetID = myso.SonnetID.astype("category")
myso.SonnetID = myso.SonnetID.cat.set_categories(full_ids)

for idx, row in myso.sort_values(["SonnetID"]).iterrows():
    print(f"\n== {row['SonnetID']}\n")
    print(format_sonnet(row['Text']))
# Out:
# == LopeDeVega_1111
#
# ¿Hay alguna mujer que más confusa
# viva en amor que yo? ¿Qué hechizo extraño
# me lleva, por los pasos de mi daño,
# adonde el mismo amor no siente excusa?
#
# Parece que el espejo de Medusa
# convierte mi razón en este engaño;
# pues amo diestra en tanto desengaño,
# sin duda que el amor es ciencia infusa.
#
# Ya me parece que es mujer hermosa
# esto que adoro, ya que un hombre veo,
# ya me siento contenta y ya quejosa.
#
# Pero, pues ya lo quiero, bien me empleo;
# que el alma puede amar cualquiera cosa
# si deja aparte el natural deseo.
#
# == FernandoDeHerrera_245
#
# ¡Oh cara perdición! ¡oh dulce engaño!
# suave mal, sabroso descontento,
# amado error del tierno pensamiento,
# luz, que nunca descubre el desengaño,
#
# puerta por la cual entra el bien y el daño,
# descanso y pena grave del tormento,
# vida del mal, alma del sufrimiento,
# de confusión revuelta, cerco extraño,
#
# vario mar de tormenta y de bonanza,
# segura playa y peligroso puerto,
# ...

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
myso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 20096 to 77014
# Data columns (total 61 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 20 non-null     object
#  1   SonnetID           20 non-null     category
#  2   Incipit            20 non-null     object
#  3   AuthorID           20 non-null     object
#  4   Author             20 non-null     object
#  5   Gender             20 non-null     object
#  6   Date               20 non-null     object
#  7   LineNumber         20 non-null     object
#  8   StanzaNumber       20 non-null     float64
#  9   Text               20 non-null     object
#  10  Call               20 non-null     object
#  11  Echo               20 non-null     object
#  12  Set                20 non-null     object
#  13  Corpus             20 non-null     object
#  14  CallLemma          20 non-null     object
#  15  EchoLemma          20 non-null     object
# ...

# %% [markdown]
# Create call-echo signatures

# %%
myso[['SonnetID', 'Text']]
# Out:
#                                      SonnetID  \
# 20096                BernardinoDeRebolledo_50
# 23151                DiegoHurtadoDeMendoza_37
# 24312                   DiegoXimenezAyllon_49
# 26178  FcodeBorjaYAragonPrincipeEsquilache_70
# 26708                   FernandoDeHerrera_105
# 27058                   FernandoDeHerrera_128
# 27746                   FernandoDeHerrera_173
# 30654                    FernandoDeHerrera_74
# 30990                    FernandoDeHerrera_96
# 32307                   FranciscoDeLaTorre_35
# 34102                    GarcilasoDeLaVega_19
# 35245                              Gongora_52
# 37727                    GutierreDeCetina_202
# 46102                         JuanDeArguijo_2
# 47571                JuanDeTassisYPeralta_114
# 49996                 JuanDeTassisYPeralta_88
# 52209                         LopeDeVega_1104
# 64387                          LopeDeVega_683
# 68563                          LopeDeVega_955
# ...

# %% [markdown]
# ## Working with rhyme-echo signatures

# %%
cdf['sig'] = cdf[['valence_call_b', 'valence_echo_b']].apply(lambda row: ''.join(row.values.astype(str)), axis=1)

# %% [markdown]
# Extract only sonnet id and signature

# %%
sdf = cdf[['SonnetID', 'sig']]

# %%
# https://stackoverflow.com/a/24112443/16449778

sdfg = sdf.groupby(['SonnetID']).aggregate(lambda tdf: tdf.unique().tolist())

# %%
sdfg['sigsort'] = sdfg['sig'].apply(sorted)

# %% [markdown]
# Extract poems with only two types of signatures to see if they include missing values (9)

# %%
sdfg.loc[sdfg['sigsort'].apply(len) == 2][['sigsort']]
# Out:
#                         sigsort
# SonnetID
# CristobalDeVirues_4    [11, 19]
# FernandoDeHerrera_209  [01, 19]
# FernandoDeHerrera_260  [11, 19]
# Gongora_67             [19, 99]
# HernandodeAcunya_22    [11, 19]
# HernandodeAcunya_83    [11, 19]
# LopeDeVega_1131        [00, 09]
# LopeDeVega_677         [11, 19]
# LopeDeVega_86          [11, 19]
# MiraDeAmescua_17       [11, 19]
# s217g_0457_03          [11, 19]
# s347g_0806             [11, 19]
# s482g_1007             [11, 19]

# %% [markdown]
# No poem with no missing values
